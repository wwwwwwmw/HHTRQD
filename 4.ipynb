# %%
# %pip install pandas numpy scikit-learn pyarrow

import pandas as pd
import numpy as np
import warnings
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.preprocessing import LabelEncoder

warnings.filterwarnings('ignore')

# --- HÀM ĐỌC DỮ LIỆU ---
def load_data_optimized(file_path):
    print(f"🔄 Đang đọc file '{file_path}'...")

    column_types = {
        'manufacturer': 'string',
        'model': 'string',
        'year': 'int32',
        'mileage': 'float32',
        'price': 'float32',
        'mpg': 'string',
        'fuel_type': 'string',
        'engine': 'string',
        'accidents_or_damage': 'float32',
        'one_owner': 'float32',
        'driver_rating': 'float32'
    }

    cols = list(column_types.keys())

    # 🔴 BẮT BUỘC PHẢI CÓ FILE
    try:
        df = pd.read_csv(
            file_path,
            usecols=cols,
            dtype=column_types,
            engine='pyarrow'
        )
    except FileNotFoundError:
        raise FileNotFoundError(
            f"❌ Không tìm thấy file '{file_path}'. "
            "Vui lòng kiểm tra lại đường dẫn hoặc tên file."
        )
    except Exception as e:
        # fallback nếu pyarrow lỗi
        df = pd.read_csv(
            file_path,
            usecols=cols,
            dtype=column_types
        )

    # =========================
    # ✅ XỬ LÝ GIÁ TRỊ THIẾU ĐÚNG KIỂU
    # =========================

    # Cột số → fill 0
    num_cols = df.select_dtypes(include=['number']).columns
    df[num_cols] = df[num_cols].fillna(0)

    # Cột text → fill 'Unknown'
    str_cols = df.select_dtypes(include=['string']).columns
    df[str_cols] = df[str_cols].fillna('Unknown')

    print(f"✅ Đã tải xong {len(df):,} dòng dữ liệu.")
    return df


# --- CHẠY ---
df_raw = load_data_optimized('cars.csv')
df_raw.head()
# Out:
# 🔄 Đang đọc file 'cars.csv'...
# ✅ Đã tải xong 762,091 dòng dữ liệu.
#   manufacturer            model  year   mileage    price    mpg fuel_type  \
# 0        Acura  ILX Hybrid 1.5L  2013   92945.0  13988.0  39-38  Gasoline
# 1        Acura  ILX Hybrid 1.5L  2013   47645.0  17995.0  39-38    Hybrid
# 2        Acura  ILX Hybrid 1.5L  2013   53422.0  17000.0  39-38    Hybrid
# 3        Acura  ILX Hybrid 1.5L  2013  117598.0  14958.0  39-38    Hybrid
# 4        Acura  ILX Hybrid 1.5L  2013  114865.0  14498.0  39-38    Hybrid
#
#                                               engine  accidents_or_damage  \
# 0  1.5L I-4 i-VTEC variable valve control, engine...                  0.0
# 1                        1.5L I4 8V MPFI SOHC Hybrid                  1.0
# 2                        1.5L I4 8V MPFI SOHC Hybrid                  0.0
# 3                        1.5L I4 8V MPFI SOHC Hybrid                  0.0
# 4                        1.5L I4 8V MPFI SOHC Hybrid                  1.0
#
#    one_owner  driver_rating
# 0        0.0            4.4
# 1        1.0            4.4
# 2        1.0            4.4
# 3        1.0            4.4
# 4        0.0            4.4

# %%
print("🤖 Đang huấn luyện AI đánh giá rủi ro...")

# 1. Tạo nhãn Rủi ro giả lập để dạy máy
def create_risk_label(row):
    score = 0
    if row['accidents_or_damage'] == 1: score += 3 
    if row['year'] < 2015: score += 1              
    if row['mileage'] > 100000: score += 2         
    if row['one_owner'] == 0: score += 1           
    
    if score <= 1: return 'Low'
    elif score <= 3: return 'Medium'
    else: return 'High'

# Lấy mẫu train
df_train = df_raw.sample(min(50000, len(df_raw))).copy() 
df_train['Risk_Level'] = df_train.apply(create_risk_label, axis=1)

# 2. Huấn luyện Random Forest
features = ['year', 'mileage', 'accidents_or_damage', 'one_owner', 'driver_rating']
X = df_train[features]
y = df_train['Risk_Level']

clf = RandomForestClassifier(n_estimators=50, random_state=42)
clf.fit(X, y)

print(f"✅ AI đã học xong!")
# Out:
# 🤖 Đang huấn luyện AI đánh giá rủi ro...
# ✅ AI đã học xong!

# %%
# =======================================================
# NHẬP ĐỘ QUAN TRỌNG TẠI ĐÂY
# =======================================================
PRICE_vs_YEAR      = 3      # Giá vs Năm
PRICE_vs_MILEAGE   = 2      # Giá vs ODO
PRICE_vs_MPG       = 5      
PRICE_vs_ACCIDENTS = 1      
PRICE_vs_BRAND     = 2      
PRICE_vs_FUEL      = 3      
PRICE_vs_ENGINE    = 5      

YEAR_vs_MILEAGE    = 1/2    
YEAR_vs_MPG        = 2      
YEAR_vs_ACCIDENTS  = 1/3    
YEAR_vs_BRAND      = 1      
YEAR_vs_FUEL       = 2      
YEAR_vs_ENGINE     = 3      

MILEAGE_vs_MPG       = 3    
MILEAGE_vs_ACCIDENTS = 1/2  
MILEAGE_vs_BRAND     = 2    
MILEAGE_vs_FUEL      = 2    
MILEAGE_vs_ENGINE    = 3

MPG_vs_ACCIDENTS     = 1/5  
MPG_vs_BRAND         = 1/2  
MPG_vs_FUEL          = 1    
MPG_vs_ENGINE        = 2    

ACCIDENTS_vs_BRAND   = 3    
ACCIDENTS_vs_FUEL    = 3    
ACCIDENTS_vs_ENGINE  = 5    

BRAND_vs_FUEL        = 2    
BRAND_vs_ENGINE      = 3    

FUEL_vs_ENGINE       = 2    

# Tính trọng số
def get_ahp_weights():
    n = 8
    matrix = np.ones((n, n))
    def set_val(i, j, val): matrix[i, j] = val; matrix[j, i] = 1 / val

    # [0:Price, 1:Year, 2:Mileage, 3:MPG, 4:Accidents, 5:Brand, 6:Fuel, 7:Engine]
    set_val(0, 1, PRICE_vs_YEAR); set_val(0, 2, PRICE_vs_MILEAGE); set_val(0, 3, PRICE_vs_MPG)
    set_val(0, 4, PRICE_vs_ACCIDENTS); set_val(0, 5, PRICE_vs_BRAND); set_val(0, 6, PRICE_vs_FUEL); set_val(0, 7, PRICE_vs_ENGINE)
    set_val(1, 2, YEAR_vs_MILEAGE); set_val(1, 3, YEAR_vs_MPG); set_val(1, 4, YEAR_vs_ACCIDENTS)
    set_val(1, 5, YEAR_vs_BRAND); set_val(1, 6, YEAR_vs_FUEL); set_val(1, 7, YEAR_vs_ENGINE)
    set_val(2, 3, MILEAGE_vs_MPG); set_val(2, 4, MILEAGE_vs_ACCIDENTS); set_val(2, 5, MILEAGE_vs_BRAND)
    set_val(2, 6, MILEAGE_vs_FUEL); set_val(2, 7, MILEAGE_vs_ENGINE)
    set_val(3, 4, MPG_vs_ACCIDENTS); set_val(3, 5, MPG_vs_BRAND); set_val(3, 6, MPG_vs_FUEL); set_val(3, 7, MPG_vs_ENGINE)
    set_val(4, 5, ACCIDENTS_vs_BRAND); set_val(4, 6, ACCIDENTS_vs_FUEL); set_val(4, 7, ACCIDENTS_vs_ENGINE)
    set_val(5, 6, BRAND_vs_FUEL); set_val(5, 7, BRAND_vs_ENGINE)
    set_val(6, 7, FUEL_vs_ENGINE)
    
    return (matrix / matrix.sum(axis=0)).mean(axis=1)

weights = get_ahp_weights()
print("✅ Đã tính xong trọng số AHP!")
# Out:
# ✅ Đã tính xong trọng số AHP!

# %%
def process_data(df, weights, ai_model):
    df = df.copy()
    
    # --- 1. CHUẨN BỊ DỮ LIỆU TÍNH AHP ---
    # MPG
    def parse_mpg(val):
        try:
            s = str(val)
            if '-' in s: return (float(s.split('-')[0]) + float(s.split('-')[1])) / 2
            return float(s)
        except: return 0
    df['mpg_num'] = df['mpg'].apply(parse_mpg)

    # Nhiên liệu & Thương hiệu & Động cơ
    def score_fuel(val):
        val = str(val).lower()
        if 'electric' in val or 'hybrid' in val: return 1.0 
        if 'gasoline' in val: return 0.5   
        return 0.3
    df['fuel_score'] = df['fuel_type'].apply(score_fuel)

    brand_counts = df['manufacturer'].value_counts(normalize=True)
    df['brand_score'] = df['manufacturer'].map(brand_counts)
    
    le = LabelEncoder()
    df['engine_score'] = le.fit_transform(df['engine'].astype(str))
    if df['engine_score'].max() != df['engine_score'].min():
         df['engine_score'] = (df['engine_score'] - df['engine_score'].min()) / (df['engine_score'].max() - df['engine_score'].min())
    else: df['engine_score'] = 0

    # --- 2. TÍNH ĐIỂM AHP ---
    df_norm = pd.DataFrame()
    # Nhóm Càng thấp càng tốt
    for col in ['price', 'mileage', 'accidents_or_damage']:
        val = df[col].astype(float)
        df_norm[col] = (val.max() - val) / (val.max() - val.min()) if val.max() != val.min() else 0
    # Nhóm Càng cao càng tốt
    for col_raw, col_norm in [('year', 'year'), ('mpg_num', 'mpg'), ('brand_score', 'brand'), ('fuel_score', 'fuel'), ('engine_score', 'engine')]:
        val = df[col_raw].astype(float)
        df_norm[col_norm] = (val - val.min()) / (val.max() - val.min()) if val.max() != val.min() else 0
    
    df['AHP_Score'] = (
        df_norm['price'] * weights[0] + df_norm['year'] * weights[1] +
        df_norm['mileage'] * weights[2] + df_norm['mpg'] * weights[3] +
        df_norm['accidents_or_damage'] * weights[4] + df_norm['brand'] * weights[5] +
        df_norm['fuel'] * weights[6] + df_norm['engine'] * weights[7]
    )
    
    # --- 3. LỌC TOP 20 ---
    top_20 = df.sort_values(by='AHP_Score', ascending=False).head(20).copy()
    
    # --- 4. CHẠY AI CHO TOP 20 ---
    ai_features = ['year', 'mileage', 'accidents_or_damage', 'one_owner', 'driver_rating']
    top_20['Predicted_Risk'] = ai_model.predict(top_20[ai_features])
    
    # Giải thích
    def explain_why(row):
        reasons = []
        if row['accidents_or_damage'] == 1: reasons.append("Từng tai nạn")
        if row['year'] < 2015: reasons.append(f"Đời sâu ({row['year']})")
        if row['mileage'] > 100000: reasons.append(f"Odo cao")
        if row['one_owner'] == 0: reasons.append("Nhiều chủ")
        if row['driver_rating'] < 4.0: reasons.append(f"Rating thấp")
        if not reasons: return "✅ An toàn"
        return "⚠️ " + ", ".join(reasons)

    top_20['Reason_Explanation'] = top_20.apply(explain_why, axis=1)
    
    return top_20

final_top_20 = process_data(df_raw, weights, clf)
print("✅ Đã xử lý xong dữ liệu!")
# Out:
# ✅ Đã xử lý xong dữ liệu!

# %%
# Format hiển thị
format_dict = {'price': '${:,.0f}', 'mileage': '{:,.0f}', 'AHP_Score': '{:.4f}'}

def highlight_risk(val):
    if val == 'High': return 'color: red; font-weight: bold'
    if val == 'Low': return 'color: green; font-weight: bold'
    return 'color: orange'

# ==============================================================================
# BẢNG 1: CHỈ CÓ THÔNG TIN XE VÀ ĐIỂM AHP (Xếp hạng theo sở thích)
# ==============================================================================
print("\n" + "="*100)
print("📌 BẢNG 1: TOP 20 XE TỐT NHẤT THEO TIÊU CHÍ AHP (CHƯA ĐÁNH GIÁ RỦI RO)")
print("="*100)

cols_ahp = [
    'manufacturer', 'model', 'price', 'year', 'mileage', 
    'mpg', 'fuel_type', 'engine', 'AHP_Score'
]

# Hiển thị
try:
    display(final_top_20[cols_ahp].style.format(format_dict))
except:
    print(final_top_20[cols_ahp].to_string(index=False))

# Xuất CSV Bảng 1
final_top_20[cols_ahp].to_csv('bang_1_ahp_ranking.csv', index=False)
# Out:
# ====================================================================================================
# 📌 BẢNG 1: TOP 20 XE TỐT NHẤT THEO TIÊU CHÍ AHP (CHƯA ĐÁNH GIÁ RỦI RO)
# ====================================================================================================
# <style type="text/css">
# </style>
# <table id="T_c9415">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c9415_level0_col0" class="col_heading level0 col0" >manufacturer</th>
#       <th id="T_c9415_level0_col1" class="col_heading level0 col1" >model</th>
#       <th id="T_c9415_level0_col2" class="col_heading level0 col2" >price</th>
#       <th id="T_c9415_level0_col3" class="col_heading level0 col3" >year</th>
#       <th id="T_c9415_level0_col4" class="col_heading level0 col4" >mileage</th>
#       <th id="T_c9415_level0_col5" class="col_heading level0 col5" >mpg</th>
#       <th id="T_c9415_level0_col6" class="col_heading level0 col6" >fuel_type</th>
#       <th id="T_c9415_level0_col7" class="col_heading level0 col7" >engine</th>
#       <th id="T_c9415_level0_col8" class="col_heading level0 col8" >AHP_Score</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c9415_level0_row0" class="row_heading level0 row0" >231283</th>
#       <td id="T_c9415_row0_col0" class="data row0 col0" >Ford</td>
#       <td id="T_c9415_row0_col1" class="data row0 col1" >Maverick</td>
#       <td id="T_c9415_row0_col2" class="data row0 col2" >$42,971</td>
#       <td id="T_c9415_row0_col3" class="data row0 col3" >2023</td>
#       <td id="T_c9415_row0_col4" class="data row0 col4" >507</td>
#       <td id="T_c9415_row0_col5" class="data row0 col5" >40-33</td>
#       <td id="T_c9415_row0_col6" class="data row0 col6" >Hybrid</td>
#       <td id="T_c9415_row0_col7" class="data row0 col7" >Gas/Electric I-4 2.5 L/152</td>
#       <td id="T_c9415_row0_col8" class="data row0 col8" >0.9548</td>
#     </tr>
#     <tr>
#       <th id="T_c9415_level0_row1" class="row_heading level0 row1" >231425</th>
#       <td id="T_c9415_row1_col0" class="data row1 col0" >Ford</td>
#       <td id="T_c9415_row1_col1" class="data row1 col1" >Maverick LARIAT</td>
#       <td id="T_c9415_row1_col2" class="data row1 col2" >$44,971</td>
#       <td id="T_c9415_row1_col3" class="data row1 col3" >2023</td>
#       <td id="T_c9415_row1_col4" class="data row1 col4" >768</td>
#       <td id="T_c9415_row1_col5" class="data row1 col5" >40-33</td>
#       <td id="T_c9415_row1_col6" class="data row1 col6" >Hybrid</td>
#       <td id="T_c9415_row1_col7" class="data row1 col7" >Gas/Electric I-4 2.5 L/152</td>
#       <td id="T_c9415_row1_col8" class="data row1 col8" >0.9548</td>
#     </tr>
#     <tr>
#       <th id="T_c9415_level0_row2" class="row_heading level0 row2" >231569</th>
#       <td id="T_c9415_row2_col0" class="data row2 col0" >Ford</td>
#       <td id="T_c9415_row2_col1" class="data row2 col1" >Maverick XLT</td>
#       <td id="T_c9415_row2_col2" class="data row2 col2" >$30,788</td>
#       <td id="T_c9415_row2_col3" class="data row2 col3" >2022</td>
#       <td id="T_c9415_row2_col4" class="data row2 col4" >10,493</td>
#       <td id="T_c9415_row2_col5" class="data row2 col5" >42-33</td>
#       <td id="T_c9415_row2_col6" class="data row2 col6" >Hybrid</td>
#       <td id="T_c9415_row2_col7" class="data row2 col7" >Gas/Electric I-4 2.5 L/152</td>
#       <td id="T_c9415_row2_col8" class="data row2 col8" >0.9530</td>
#     </tr>
#     <tr>
#       <th id="T_c9415_level0_row3" class="row_heading level0 row3" >231652</th>
#       <td id="T_c9415_row3_col0" class="data row3 col0" >Ford</td>
#       <td id="T_c9415_row3_col1" class="data row3 col1" >Maverick XLT</td>
#       <td id="T_c9415_row3_col2" class="data row3 col2" >$35,686</td>
#       <td id="T_c9415_row3_col3" class="data row3 col3" >2022</td>
#       <td id="T_c9415_row3_col4" class="data row3 col4" >11,050</td>
#       <td id="T_c9415_row3_col5" class="data row3 col5" >42-33</td>
#       <td id="T_c9415_row3_col6" class="data row3 col6" >Hybrid</td>
#       <td id="T_c9415_row3_col7" class="data row3 col7" >Gas/Electric I-4 2.5 L/152</td>
#       <td id="T_c9415_row3_col8" class="data row3 col8" >0.9529</td>
#     </tr>
#     <tr>
#       <th id="T_c9415_level0_row4" class="row_heading level0 row4" >219151</th>
#       <td id="T_c9415_row4_col0" class="data row4 col0" >Ford</td>
#       <td id="T_c9415_row4_col1" class="data row4 col1" >Fusion Hybrid SE</td>
#       <td id="T_c9415_row4_col2" class="data row4 col2" >$21,995</td>
#       <td id="T_c9415_row4_col3" class="data row4 col3" >2018</td>
#       <td id="T_c9415_row4_col4" class="data row4 col4" >45,070</td>
#       <td id="T_c9415_row4_col5" class="data row4 col5" >43-41</td>
#       <td id="T_c9415_row4_col6" class="data row4 col6" >Hybrid</td>
#       <td id="T_c9415_row4_col7" class="data row4 col7" >Gas/Electric I-4 2.0 L/122</td>
#       <td id="T_c9415_row4_col8" class="data row4 col8" >0.9468</td>
#     </tr>
#     <tr>
#       <th id="T_c9415_level0_row5" class="row_heading level0 row5" >219318</th>
#       <td id="T_c9415_row5_col0" class="data row5 col0" >Ford</td>
#       <td id="T_c9415_row5_col1" class="data row5 col1" >Fusion Hybrid SE</td>
#       <td id="T_c9415_row5_col2" class="data row5 col2" >$21,417</td>
#       <td id="T_c9415_row5_col3" class="data row5 col3" >2018</td>
#       <td id="T_c9415_row5_col4" class="data row5 col4" >48,106</td>
#       <td id="T_c9415_row5_col5" class="data row5 col5" >43-41</td>
#       <td id="T_c9415_row5_col6" class="data row5 col6" >Hybrid</td>
#       <td id="T_c9415_row5_col7" class="data row5 col7" >Gas/Electric I-4 2.0 L/122</td>
#       <td id="T_c9415_row5_col8" class="data row5 col8" >0.9464</td>
#     </tr>
#     <tr>
#       <th id="T_c9415_level0_row6" class="row_heading level0 row6" >198787</th>
#       <td id="T_c9415_row6_col0" class="data row6 col0" >Ford</td>
#       <td id="T_c9415_row6_col1" class="data row6 col1" >F-150 King Ranch</td>
#       <td id="T_c9415_row6_col2" class="data row6 col2" >$63,998</td>
#       <td id="T_c9415_row6_col3" class="data row6 col3" >2021</td>
#       <td id="T_c9415_row6_col4" class="data row6 col4" >21,226</td>
#       <td id="T_c9415_row6_col5" class="data row6 col5" >16-22</td>
#       <td id="T_c9415_row6_col6" class="data row6 col6" >Hybrid</td>
#       <td id="T_c9415_row6_col7" class="data row6 col7" >Twin Turbo Gas/Electric V-6 3.5 L/213</td>
#       <td id="T_c9415_row6_col8" class="data row6 col8" >0.9460</td>
#     </tr>
#     <tr>
#       <th id="T_c9415_level0_row7" class="row_heading level0 row7" >200884</th>
#       <td id="T_c9415_row7_col0" class="data row7 col0" >Ford</td>
#       <td id="T_c9415_row7_col1" class="data row7 col1" >F-150 Lariat</td>
#       <td id="T_c9415_row7_col2" class="data row7 col2" >$53,726</td>
#       <td id="T_c9415_row7_col3" class="data row7 col3" >2021</td>
#       <td id="T_c9415_row7_col4" class="data row7 col4" >37,000</td>
#       <td id="T_c9415_row7_col5" class="data row7 col5" >24-22</td>
#       <td id="T_c9415_row7_col6" class="data row7 col6" >Hybrid</td>
#       <td id="T_c9415_row7_col7" class="data row7 col7" >V6 Cylinder Engine</td>
#       <td id="T_c9415_row7_col8" class="data row7 col8" >0.9459</td>
#     </tr>
#     <tr>
#       <th id="T_c9415_level0_row8" class="row_heading level0 row8" >207165</th>
#       <td id="T_c9415_row8_col0" class="data row8 col0" >Ford</td>
#       <td id="T_c9415_row8_col1" class="data row8 col1" >C-Max Energi SEL</td>
#       <td id="T_c9415_row8_col2" class="data row8 col2" >$18,598</td>
#       <td id="T_c9415_row8_col3" class="data row8 col3" >2016</td>
#       <td id="T_c9415_row8_col4" class="data row8 col4" >32,600</td>
#       <td id="T_c9415_row8_col5" class="data row8 col5" >40-36</td>
#       <td id="T_c9415_row8_col6" class="data row8 col6" >Hybrid</td>
#       <td id="T_c9415_row8_col7" class="data row8 col7" >Gas/Electric I-4 2.0 L/122</td>
#       <td id="T_c9415_row8_col8" class="data row8 col8" >0.9449</td>
#     </tr>
#     <tr>
#       <th id="T_c9415_level0_row9" class="row_heading level0 row9" >219108</th>
#       <td id="T_c9415_row9_col0" class="data row9 col0" >Ford</td>
#       <td id="T_c9415_row9_col1" class="data row9 col1" >Fusion Hybrid SE</td>
#       <td id="T_c9415_row9_col2" class="data row9 col2" >$17,798</td>
#       <td id="T_c9415_row9_col3" class="data row9 col3" >2019</td>
#       <td id="T_c9415_row9_col4" class="data row9 col4" >79,249<

# %%
# ==============================================================================
# BẢNG 2: KẾT HỢP ĐÁNH GIÁ RỦI RO CỦA AI (Hỗ trợ ra quyết định)
# ==============================================================================
print("\n" + "="*100)
print("🤖 BẢNG 2: KẾT QUẢ PHÂN TÍCH RỦI RO TỪ AI (CHO TOP 20 XE TRÊN)")
print("="*100)

cols_risk = [
    'manufacturer', 'model', 'price', 'year', 
    'AHP_Score',        # Điểm cũ
    'Predicted_Risk',   # AI thêm vào
    'Reason_Explanation'# Lý do
]

# Hiển thị
try:
    display(final_top_20[cols_risk].style.format(format_dict).applymap(highlight_risk, subset=['Predicted_Risk']))
except:
    print(final_top_20[cols_risk].to_string(index=False))

# Xuất CSV Bảng 2
final_top_20[cols_risk].to_csv('bang_2_ai_risk.csv', index=False)
print("\n✅ Đã xuất 2 file: 'bang_1_ahp_ranking.csv' và 'bang_2_ai_risk.csv' thành công!")
# Out:
# ====================================================================================================
# 🤖 BẢNG 2: KẾT QUẢ PHÂN TÍCH RỦI RO TỪ AI (CHO TOP 20 XE TRÊN)
# ====================================================================================================
# <style type="text/css">
# #T_3f09e_row0_col5, #T_3f09e_row1_col5, #T_3f09e_row2_col5, #T_3f09e_row3_col5, #T_3f09e_row4_col5, #T_3f09e_row5_col5, #T_3f09e_row6_col5, #T_3f09e_row7_col5, #T_3f09e_row8_col5, #T_3f09e_row9_col5, #T_3f09e_row10_col5, #T_3f09e_row11_col5, #T_3f09e_row12_col5, #T_3f09e_row13_col5, #T_3f09e_row14_col5, #T_3f09e_row15_col5, #T_3f09e_row16_col5, #T_3f09e_row17_col5, #T_3f09e_row18_col5, #T_3f09e_row19_col5 {
#   color: green;
#   font-weight: bold;
# }
# </style>
# <table id="T_3f09e">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_3f09e_level0_col0" class="col_heading level0 col0" >manufacturer</th>
#       <th id="T_3f09e_level0_col1" class="col_heading level0 col1" >model</th>
#       <th id="T_3f09e_level0_col2" class="col_heading level0 col2" >price</th>
#       <th id="T_3f09e_level0_col3" class="col_heading level0 col3" >year</th>
#       <th id="T_3f09e_level0_col4" class="col_heading level0 col4" >AHP_Score</th>
#       <th id="T_3f09e_level0_col5" class="col_heading level0 col5" >Predicted_Risk</th>
#       <th id="T_3f09e_level0_col6" class="col_heading level0 col6" >Reason_Explanation</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_3f09e_level0_row0" class="row_heading level0 row0" >231283</th>
#       <td id="T_3f09e_row0_col0" class="data row0 col0" >Ford</td>
#       <td id="T_3f09e_row0_col1" class="data row0 col1" >Maverick</td>
#       <td id="T_3f09e_row0_col2" class="data row0 col2" >$42,971</td>
#       <td id="T_3f09e_row0_col3" class="data row0 col3" >2023</td>
#       <td id="T_3f09e_row0_col4" class="data row0 col4" >0.9548</td>
#       <td id="T_3f09e_row0_col5" class="data row0 col5" >Low</td>
#       <td id="T_3f09e_row0_col6" class="data row0 col6" >✅ An toàn</td>
#     </tr>
#     <tr>
#       <th id="T_3f09e_level0_row1" class="row_heading level0 row1" >231425</th>
#       <td id="T_3f09e_row1_col0" class="data row1 col0" >Ford</td>
#       <td id="T_3f09e_row1_col1" class="data row1 col1" >Maverick LARIAT</td>
#       <td id="T_3f09e_row1_col2" class="data row1 col2" >$44,971</td>
#       <td id="T_3f09e_row1_col3" class="data row1 col3" >2023</td>
#       <td id="T_3f09e_row1_col4" class="data row1 col4" >0.9548</td>
#       <td id="T_3f09e_row1_col5" class="data row1 col5" >Low</td>
#       <td id="T_3f09e_row1_col6" class="data row1 col6" >✅ An toàn</td>
#     </tr>
#     <tr>
#       <th id="T_3f09e_level0_row2" class="row_heading level0 row2" >231569</th>
#       <td id="T_3f09e_row2_col0" class="data row2 col0" >Ford</td>
#       <td id="T_3f09e_row2_col1" class="data row2 col1" >Maverick XLT</td>
#       <td id="T_3f09e_row2_col2" class="data row2 col2" >$30,788</td>
#       <td id="T_3f09e_row2_col3" class="data row2 col3" >2022</td>
#       <td id="T_3f09e_row2_col4" class="data row2 col4" >0.9530</td>
#       <td id="T_3f09e_row2_col5" class="data row2 col5" >Low</td>
#       <td id="T_3f09e_row2_col6" class="data row2 col6" >✅ An toàn</td>
#     </tr>
#     <tr>
#       <th id="T_3f09e_level0_row3" class="row_heading level0 row3" >231652</th>
#       <td id="T_3f09e_row3_col0" class="data row3 col0" >Ford</td>
#       <td id="T_3f09e_row3_col1" class="data row3 col1" >Maverick XLT</td>
#       <td id="T_3f09e_row3_col2" class="data row3 col2" >$35,686</td>
#       <td id="T_3f09e_row3_col3" class="data row3 col3" >2022</td>
#       <td id="T_3f09e_row3_col4" class="data row3 col4" >0.9529</td>
#       <td id="T_3f09e_row3_col5" class="data row3 col5" >Low</td>
#       <td id="T_3f09e_row3_col6" class="data row3 col6" >✅ An toàn</td>
#     </tr>
#     <tr>
#       <th id="T_3f09e_level0_row4" class="row_heading level0 row4" >219151</th>
#       <td id="T_3f09e_row4_col0" class="data row4 col0" >Ford</td>
#       <td id="T_3f09e_row4_col1" class="data row4 col1" >Fusion Hybrid SE</td>
#       <td id="T_3f09e_row4_col2" class="data row4 col2" >$21,995</td>
#       <td id="T_3f09e_row4_col3" class="data row4 col3" >2018</td>
#       <td id="T_3f09e_row4_col4" class="data row4 col4" >0.9468</td>
#       <td id="T_3f09e_row4_col5" class="data row4 col5" >Low</td>
#       <td id="T_3f09e_row4_col6" class="data row4 col6" >⚠️ Nhiều chủ</td>
#     </tr>
#     <tr>
#       <th id="T_3f09e_level0_row5" class="row_heading level0 row5" >219318</th>
#       <td id="T_3f09e_row5_col0" class="data row5 col0" >Ford</td>
#       <td id="T_3f09e_row5_col1" class="data row5 col1" >Fusion Hybrid SE</td>
#       <td id="T_3f09e_row5_col2" class="data row5 col2" >$21,417</td>
#       <td id="T_3f09e_row5_col3" class="data row5 col3" >2018</td>
#       <td id="T_3f09e_row5_col4" class="data row5 col4" >0.9464</td>
#       <td id="T_3f09e_row5_col5" class="data row5 col5" >Low</td>
#       <td id="T_3f09e_row5_col6" class="data row5 col6" >⚠️ Nhiều chủ</td>
#     </tr>
#     <tr>
#       <th id="T_3f09e_level0_row6" class="row_heading level0 row6" >198787</th>
#       <td id="T_3f09e_row6_col0" class="data row6 col0" >Ford</td>
#       <td id="T_3f09e_row6_col1" class="data row6 col1" >F-150 King Ranch</td>
#       <td id="T_3f09e_row6_col2" class="data row6 col2" >$63,998</td>
#       <td id="T_3f09e_row6_col3" class="data row6 col3" >2021</td>
#       <td id="T_3f09e_row6_col4" class="data row6 col4" >0.9460</td>
#       <td id="T_3f09e_row6_col5" class="data row6 col5" >Low</td>
#       <td id="T_3f09e_row6_col6" class="data row6 col6" >⚠️ Nhiều chủ</td>
#     </tr>
#     <tr>
#       <th id="T_3f09e_level0_row7" class="row_heading level0 row7" >200884</th>
#       <td id="T_3f09e_row7_col0" class="data row7 col0" >Ford</td>
#       <td id="T_3f09e_row7_col1" class="data row7 col1" >F-150 Lariat</td>
#       <td id="T_3f09e_row7_col2" class="data row7 col2" >$53,726</td>
#       <td id="T_3f09e_row7_col3" class="data row7 col3" >2021</td>
#       <td id="T_3f09e_row7_col4" class="data row7 col4" >0.9459</td>
#       <td id="T_3f09e_row7_col5" class="data row7 col5" >Low</td>
#       <td id="T_3f09e_row7_col6" class="data row7 col6" >✅ An toàn</td>
#     </tr>
#     <tr>
#       <th id="T_3f09e_level0_row8" class="row_heading level0 row8" >207165</th>
#       <td id="T_3f09e_row8_col0" class="data row8 col0" >Ford</td>
#       <td id="T_3f09e_row8_col1" class="data row8 col1" >C-Max Energi SEL</td>
#       <td id="T_3f09e_row8_col2" class="data row8 col2" >$18,598</td>
#       <td id="T_3f09e_row8_col3" class="data row8 col3" >2016</td>
#       <td id="T_3f09e_row8_col4" class="data row8 col4" >0.9449</td>
#       <td id="T_3f09e_row8_col5" class="data row8 col5" >Low</td>
#       <td id="T_3f09e_row8_col6" class="data row8 col6" >⚠️ Nhiều chủ</td>
#     </tr>
#     <tr>
#       <th id="T_3f09e_level0_row9" class="row_heading level0 row9" >219108</th>
#       <td id="T_3f09e_row9_col0" class="data row9 col0" >Ford</td>
#       <td id="T_3f09e_row9_col1" class="data row9 col1" >Fusion Hybrid SE</td>
#       <td id="T_3f09e_row9_col2" class="data row9 col2" >$17,798</td>
#       <td id="T_3f09e_row9_col3" class="data row9 col3" >2019</td>
#       <td id="T_3f09e_row9_col4" class="data row9 col4" >0.9432</td>
#       <td id="T_3f09e_row9_col5" class="data row9 col5" >Low</td>
#       <td id="T_3f09e_row9_col6" class="data row9 col6" >✅ An toàn</td>
#     </tr>
#     <tr>
#       <th id="T_3f09e_level0_row10" class="row_heading level0 row10" >219980</th>
#       <td id="T_3f09e_row10_col0" class="data row10 col0" >Ford</td>
#       <td id="T_3f09e_row10_col1" class="data row10 col1" >Fusion Hybrid SE</td>
#       <td id="T_3f09e_row10_col2" class="data row10 col2" >$16,988</td>
#       <td id="T_3f09e_row10_col3" class="data row10 col3" >2019</td>
#       <td id="T_3f09e_row10_col4" class="data row10 col4" >0.9426</td>
#       <td id="T_3f09e_row10_col5" class="data row10 col5" >Low</td>
#       <td id="T_3f09e_row10_col6" class="data row10 col6" >✅ An toàn</td>
#     </tr>
#     <tr>
#       <th id="T_3f09e_level0_row11" class="row_heading level0 row11" >219627</th>
#       <td id="T_3f09e_row11_col0" class="data row11 col0" >Ford</td>
#       <td id="T_3f09e_row11_col1" class="data row11 col1" >Fusion Hybrid SE</td>
#       <td id="T_3f09e_row11_col2" class="data row11 col2" >$18,995</td>
#       <td id="T_3f
# ✅ Đã xuất 2 file: 'bang_1_ahp_ranking.csv' và 'bang_2_ai_risk.csv' thành công!
